# %%
import pandas as pd

# %%
datos= pd.read_json('/content/TelecomX_Data (1).json')
print("Valores únicos en Churn:")
print(pd.unique(datos['Churn']))
# Out:
# Valores únicos en Churn:
# ['No' 'Yes' '']

# %%
datos
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
datos = datos[datos['Churn'].isin(['Yes', 'No'])]
datos
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Out:
# Index([], dtype='object')

# %%
custom=  pd.json_normalize(datos['customer'])
customid = (datos['customerID'])
phone=  pd.json_normalize(datos['phone'])
internet=  pd.json_normalize(datos['internet'])
account=  pd.json_normalize(datos['account'])
churn = (datos['Churn'])

datos_nuevos=pd.concat([customid,churn,custom,phone,internet,account],axis=1)
df=datos_nuevos


df["Cuentas_Diarias"] = df["Charges.Monthly"] / 30

print(df[["customerID", "Charges.Monthly", "Cuentas_Diarias"]].head())
# Out:
#    customerID  Charges.Monthly  Cuentas_Diarias
# 0  0002-ORFBO             65.6         2.186667
# 1  0003-MKNFE             59.9         1.996667
# 2  0004-TLHLJ             73.9         2.463333
# 3  0011-IGKFF             98.0         3.266667
# 4  0013-EXCHZ             83.9         2.796667

# %%
df["Charges.Total"] = pd.to_numeric(df["Charges.Total"], errors="coerce")
desc = df[["Charges.Monthly", "Charges.Total", "tenure"]].describe()

print(desc)
# Out:
#        Charges.Monthly  Charges.Total       tenure
# count      7267.000000    7256.000000  7267.000000
# mean         64.720098    2280.634213    32.346498
# std          30.129572    2268.632997    24.571773
# min          18.250000      18.800000     0.000000
# 25%          35.425000     400.225000     9.000000
# 50%          70.300000    1391.000000    29.000000
# 75%          89.875000    3785.300000    55.000000
# max         118.750000    8684.800000    72.000000

# %%
import matplotlib.pyplot as plt
df["Churn"].value_counts().plot(kind="bar", color=["skyblue", "salmon"])
plt.title("Distribución de clientes según Churn")
plt.xlabel("Churn")
plt.ylabel("Cantidad de clientes")
plt.show()

# %%
churn_gender = pd.crosstab(df["gender"], df["Churn"])

churn_gender.plot(kind="bar", stacked=True, color=["skyblue", "salmon"])
plt.title("Churn según Género")
plt.xlabel("Género")
plt.ylabel("Cantidad de clientes")
plt.legend(title="Churn")
plt.show()

# %%
churn_payment = pd.crosstab(df["PaymentMethod"], df["Churn"])

churn_payment.plot(kind="bar", stacked=True, color=["skyblue", "salmon"], figsize=(8,5))
plt.title("Churn según Método de Pago")
plt.xlabel("Método de Pago")
plt.ylabel("Cantidad de clientes")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Churn")
plt.show()

# %%
churn_contract = pd.crosstab(df["Contract"], df["Churn"])

churn_contract.plot(kind="bar", stacked=True, color=["skyblue", "salmon"])
plt.title("Churn según Tipo de Contrato")
plt.xlabel("Contrato")
plt.ylabel("Cantidad de clientes")
plt.xticks(rotation=30, ha="right")
plt.legend(title="Churn")
plt.show()

# %%
print(df.groupby("Churn")[["Charges.Total", "tenure", "Charges.Monthly"]].describe())
# Out:
#       Charges.Total                                                       \
#               count         mean          std    min       25%       50%
# Churn
#               224.0  2196.933705  2329.961954  18.90  351.0375  1163.175
# No           5163.0  2555.344141  2329.456984  18.80  577.8250  1683.600
# Yes          1869.0  1531.796094  1890.822994  18.85  134.5000   703.550
#
#                            tenure             ...             Charges.Monthly  \
#              75%      max   count       mean  ...   75%   max           count
# Churn                                         ...
#        3562.8625  8425.30   224.0  31.571429  ...  56.0  72.0           224.0
# No     4264.1250  8672.45  5174.0  37.569965  ...  61.0  72.0          5174.0
# Yes    2331.3000  8684.80  1869.0  17.979133  ...  29.0  72.0          1869.0
#
#
#             mean        std    min     25%     50%      75%     max
# Churn
#        63.412277  31.388712  18.75  28.425  69.100  90.4125  115.55
# ...

# %%
df.shape
# Out:
# (7267, 6)

# %%
columnas = list(datos.columns)
print(columnas)
# Out:
# ['customerID', 'Churn', 'customer', 'phone', 'internet', 'account']

# %%
import requests
#resultado = json.loads(datos_content)
#datos_content = requests.get('/content/TelecomX_Data.json')

custom=  pd.json_normalize(datos['customer'])
customid = (datos['customerID'])
phone=  pd.json_normalize(datos['phone'])
internet=  pd.json_normalize(datos['internet'])
account=  pd.json_normalize(datos['account'])
churn = (datos['Churn'])

datos_nuevos=pd.concat([customid,churn,custom,phone,internet,account],axis=1)

# %%
datos.columns.str.lower()

# %%
datos.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# # Informe Final: Análisis de Evasión de Clientes (Churn)
#
# La evasión de clientes o churn es un problema relevante para cualquier empresa de telecomunicaciones porque impacta directamente en los ingresos y en la estabilidad del negocio. El objetivo de este análisis fue comprender cómo se comportan los clientes, qué factores influyen en la cancelación del servicio y qué medidas se pueden tomar para reducirla.
#
# Para comenzar, se importaron los datos desde un archivo JSON. Fue necesario normalizar la estructura porque tenía información anidada en varias columnas. Durante el proceso se detectaron valores faltantes en la variable churn que fueron limpiados. También se creó una nueva variable llamada Cuentas_Diarias, calculada a partir del cargo mensual dividido en treinta días, con el fin de tener una visión más detallada del gasto diario de los clientes.
#
# El análisis exploratorio mostró que la mayoría de los clientes permanecen en la compañía, pero existe un grupo importante que cancela. Se observó que los clientes con contrato mes a mes presentan una tasa de evasión mucho más alta que aquellos con contratos de uno o dos años. También se detectó que los clientes que utilizan el método de pago Electronic check tienen mayor tendencia a abandonar el servicio. En cuanto a las variables numéricas, los clientes con pocos meses de permanencia son los que más cancelan y aquellos con cargos mensuales altos también tienen más riesgo de irse.
#
# A partir de estos hallazgos se puede concluir que la evasión está asociada con la antigüedad del cliente, el tipo de contrato y el método de pago. Los clientes nuevos, los que pagan con medios electrónicos inmediatos y los que enfrentan facturas altas son más vulnerables a abandonar la compañía.
#
# Finalmente, se recomienda incentivar contratos de mayor duración ofreciendo beneficios o descuentos, mejorar la experiencia de quienes usan Electronic check mediante la promoción de métodos de pago alternativos, diseñar ofertas personalizadas para clientes con cargos mensuales altos y aplicar programas de fidelización en los primeros meses de servicio. Estas acciones ayudarían a reducir la evasión y a fortalecer la relación con los clientes.

# %%
df = df.drop(columns=["customerID"])

# %%
cat_cols = df.select_dtypes(include=["object"]).columns

df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
conteo = df["Churn"].value_counts()
proporcion = df["Churn"].value_counts(normalize=True)

print("Conteo de clases:\n", conteo)
print("\nProporción de clases:\n", proporcion)
# Out:
# Conteo de clases:
#  Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64
#
# Proporción de clases:
#  Churn
# No     0.711986
# Yes    0.257190
#        0.030824
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

num_cols = df.select_dtypes(include=["int64", "float64"]).columns


scaler_std = StandardScaler()
df_std = df.copy()
df_std[num_cols] = scaler_std.fit_transform(df[num_cols])
scaler_minmax = MinMaxScaler()
df_minmax = df.copy()
df_minmax[num_cols] = scaler_minmax.fit_transform(df[num_cols])

# %%
df["Churn_num"] = df["Churn"].map({"No": 0, "Yes": 1})

num_df = df.select_dtypes(include=["int64", "float64"])
corr = num_df.corr()

print(corr["Churn_num"].sort_values(ascending=False))
# Out:
# Churn_num          1.000000
# Charges.Monthly    0.193356
# Cuentas_Diarias    0.193356
# SeniorCitizen      0.150889
# Charges.Total     -0.199484
# tenure            -0.352229
# Name: Churn_num, dtype: float64

# %%
plt.figure(figsize=(10,8))

cax = plt.matshow(corr, cmap="coolwarm", fignum=1)
plt.colorbar(cax)

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Matriz de correlación", pad=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2035492463.py in <cell line: 0>()
#       1 plt.figure(figsize=(10,8))
#       2
# ----> 3 cax = plt.matshow(corr, cmap="coolwarm", fignum=1)
#       4 plt.colorbar(cax)
#       5
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in matshow(A, fignum, **kwargs)
#    2671         # Extract actual aspect ratio of array and make appropriately sized
#    2672         # figure.
# -> 2673         fig = figure(fignum, figsize=figaspect(A))
#    2674         ax = fig.add_axes((0.15, 0.09, 0.775, 0.775))
#    2675     im = ax.matshow(A, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1008         num = next_num
#    1009     else:
# ...
